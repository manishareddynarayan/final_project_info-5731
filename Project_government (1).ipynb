# %%
# !pip install pyecharts==1.7.1
# Out:
# Requirement already satisfied: pyecharts==1.7.1 in c:\users\raghu vamsi\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: prettytable in c:\users\raghu vamsi\anaconda3\lib\site-packages (from pyecharts==1.7.1) (2.4.0)
# Requirement already satisfied: simplejson in c:\users\raghu vamsi\anaconda3\lib\site-packages (from pyecharts==1.7.1) (3.17.6)
# Requirement already satisfied: jinja2 in c:\users\raghu vamsi\anaconda3\lib\site-packages (from pyecharts==1.7.1) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\raghu vamsi\anaconda3\lib\site-packages (from jinja2->pyecharts==1.7.1) (1.1.1)
# Requirement already satisfied: wcwidth in c:\users\raghu vamsi\anaconda3\lib\site-packages (from prettytable->pyecharts==1.7.1) (0.2.5)

# %%
#import libraries
from pyecharts.charts import Map,Geo
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
#import data
import pandas as pd
dataset=pd.read_csv("owid-covid-data.csv")

# %%
#change date from object data type to datetime data type
dataset["date"]=pd.to_datetime(dataset["date"])
df = dataset.sort_values(by=['date'], ascending=False) #sort data by date
map_df=df[df['date']=='2021-06-03']
map_df.reset_index(drop=True, inplace=True)
map_df
# Out:
#     iso_code      continent                   location       date  \
# 0        JEY         Europe                     Jersey 2021-06-03
# 1        MRT         Africa                 Mauritania 2021-06-03
# 2        IND           Asia                      India 2021-06-03
# 3        BFA         Africa               Burkina Faso 2021-06-03
# 4        MAR         Africa                    Morocco 2021-06-03
# ..       ...            ...                        ...        ...
# 226      PYF        Oceania           French Polynesia 2021-06-03
# 227      GGY         Europe                   Guernsey 2021-06-03
# 228      SYR           Asia                      Syria 2021-06-03
# 229      SXM  North America  Sint Maarten (Dutch part) 2021-06-03
# 230      ISL         Europe                    Iceland 2021-06-03
#
#      total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            NaN        NaN                 NaN           NaN         NaN
# 1        19695.0       45.0              50.143         464.0         0.0
# 2     28574350.0   132364.0          145556.143      340702.0      2713.0
# 3        13446.0       11.0               3.571         167.0         0.0
# 4       520423.0      395.0             328.714        9165.0         5.0
# ..           ...        ...                 ...           ...         ...
# 226          NaN        NaN                 NaN           NaN         NaN
# 227          NaN        NaN                 NaN           NaN         NaN
# 228      24591.0       32.0              32.286        1782.0         4.0
# 229          NaN        NaN                 NaN           NaN         NaN
# 230       6590.0        4.0               3.714          30.0         0.0
#
#      new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 0                    NaN  ...             NaN           NaN
# 1                  0.286  ...             NaN           NaN
# 2               3115.286  ...             1.9          20.6
# 3                  0.143  ...             1.6          23.9
# 4                  4.429  ...             0.8          47.1
# ..                   ...  ...             ...           ...
# 226                  NaN  ...             NaN           NaN
# 227                  NaN  ...             NaN           NaN
# 228                4.000  ...             NaN           NaN
# 229                  NaN  ...             NaN           NaN
# 230                0.000  ...            14.3          15.2
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       NaN                         NaN              NaN
# 1                    15.950                         NaN            64.92
# 2                    59.550                        0.53            69.66
# 3                    11.877                        0.40            61.58
# 4                       NaN                        1.10            76.68
# ..                      ...                         ...              ...
# 226                     NaN                         NaN            77.66
# 227                     NaN                         NaN              NaN
# 228                  70.598                        1.50            72.70
# 229                     NaN                         NaN            78.95
# 230                     NaN                        2.91            82.99
#
#      human_development_index  excess_mortality_cumulative_absolute  \
# 0                        NaN                                   NaN
# 1                      0.546                                   NaN
# 2                      0.645                                   NaN
# 3                      0.452                                   NaN
# 4                      0.686                                   NaN
# ..                       ...                                   ...
# 226                      NaN                                   NaN
# 227                      NaN                                   NaN
# 228                    0.567                                   NaN
# 229                      NaN                                   NaN
# 230                    0.949                                   NaN
#
#      excess_mortality_cumulative  excess_mortality  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ..                           ...               ...
# 226                          NaN               NaN
# 227                          NaN               NaN
# 228                          NaN               NaN
# 229                          NaN               NaN
# 230                          NaN               NaN
#
#      excess_mortality_cumulative_per_million
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 226                                      NaN
# 227                                      NaN
# 228                                      NaN
# 229                                      NaN
# 230                                      NaN
#
# [231 rows x 67 columns]

# %%
country=list(map_df["location"])
totalcases=list(map_df["total_cases"])

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] #prepare data for visualization
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px")) #create the map and set the size of the map
map_1.add("Total Confirmed Cases", list1, maptype="world") #add world map
map_1.set_global_opts( #set global configurations
 visualmap_opts=opts.VisualMapOpts(max_=1100000,    is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False), #show legend or not
 )
map_1.render_notebook() #show the map in the notebook directly
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="8ac7ee2236d148e29f0fb577a347a3b2" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_8ac7ee2236d148e29f0fb577a347a3b2 = echarts.init(
#                     document.getElementById('8ac7ee2236d148e29f0fb577a347a3b2'), 'white', {renderer: 'canvas'});
#                 var option_8ac7ee2236d148e29f0fb577a347a3b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px")) 
map_1.add("Total Confirmed Cases", 
 list1, maptype='world') 
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) #remove country names
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="3b4580bcfa3e4252bca793375dfdd5d8" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_3b4580bcfa3e4252bca793375dfdd5d8 = echarts.init(
#                     document.getElementById('3b4580bcfa3e4252bca793375dfdd5d8'), 'white', {renderer: 'canvas'});
#                 var option_3b4580bcfa3e4252bca793375dfdd5d8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px")) 
map_1.add("Total Confirmed Cases", 
 list1, 
 maptype='world',
 is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="afa25f73d5424497bead09d4e03217ea" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_afa25f73d5424497bead09d4e03217ea = echarts.init(
#                     document.getElementById('afa25f73d5424497bead09d4e03217ea'), 'white', {renderer: 'canvas'});
#                 var option_afa25f73d5424497bead09d4e03217ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px")) 
map_1.add("Total Confirmed Cases", 
 list1, 
 maptype='world',
 is_map_symbol_show=False) 
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=True,pieces=[
 {"min": 500000},
  {"min": 400000, "max": 499999},
 {"min": 300000, "max": 399999},
 {"min": 200000, "max": 299999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="97eb69c748b843a180a8bc32d9bd2eaf" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_97eb69c748b843a180a8bc32d9bd2eaf = echarts.init(
#                     document.getElementById('97eb69c748b843a180a8bc32d9bd2eaf'), 'white', {renderer: 'canvas'});
#                 var option_97eb69c748b843a180a8bc32d9bd2eaf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px")) 
map_1.add('Total Confirmed Cases', 
 list1,
 maptype='world',
 is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(
visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=True,pieces=[
 {"min": 500000},
 {"min": 400000, "max": 499999},
 {"min": 300000, "max": 399999},
 {"min": 200000, "max": 299999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 title_opts=opts.TitleOpts(
 title='Total Worldwide Cases of Covid19',
 subtitle='Till June 03rd,2021',
 pos_left='center',
 padding=0,
 item_gap=3,# gap between title and subtitle 
 title_textstyle_opts= opts.TextStyleOpts(color='darkblue',
 font_weight='bold',
 font_family='Courier New',
 font_size=30), 
 subtitle_textstyle_opts= opts.TextStyleOpts(color='grey',
 font_weight='bold',
 font_family='ourier New',
 font_size=13)), 
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="24254d7b4bc241f8b5198c5755187103" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_24254d7b4bc241f8b5198c5755187103 = echarts.init(
#                     document.getElementById('24254d7b4bc241f8b5198c5755187103'), 'white', {renderer: 'canvas'});
#                 var option_24254d7b4bc241f8b5198c5755187103 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px",theme=ThemeType.ROMANTIC)) 
map_1.add('Total Confirmed Cases', 
 list1,
 maptype='world',
 is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(
visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=True,pieces=[
 {"min": 500000},
 {"min": 400000, "max": 499999},
 {"min": 300000, "max": 399999},
 {"min": 200000, "max": 299999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 title_opts=opts.TitleOpts(
 title="Covid-19 Total Worldwide Cases",
 subtitle='Till June 03rd,2021',
 pos_left='center',
 padding=0,
 item_gap=2,
 title_textstyle_opts= opts.TextStyleOpts(color='darkblue',
 font_weight='bold',
 font_family='Courier New',
 font_size=30), 
 subtitle_textstyle_opts= opts.TextStyleOpts(color='grey',
 font_weight='bold',
 font_family='Courier New',
 font_size=13)), 
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic'
#         }
#     });
# </script>
#
#         <div id="2eaa82a310aa40baa39839cf8f95b8d4" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'romantic'], function(echarts) {
#                 var chart_2eaa82a310aa40baa39839cf8f95b8d4 = echarts.init(
#                     document.getElementById('2eaa82a310aa40baa39839cf8f95b8d4'), 'romantic', {renderer: 'canvas'});
#                 var option_2eaa82a310aa40baa39839cf8f95b8d4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jersey",
#                     "value": null
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 19695.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 28574350.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 13446.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 520423.0
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 97388.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": null
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 145567.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 5040390.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 1262.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 325779.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 7422.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1421.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 364702.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 24429.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 171658.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": null
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 11888.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 928588.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 100997.0
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 39092.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 6767.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 56981.0
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 49579.0
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 263252.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 284888.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 696801.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 5755675.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 244.0
#                 },
#                 {
#                     "name": "Upper middle income",
#                     "value": 51752849.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 73694.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 380207.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1395909.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 2874092.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 94011.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 188.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 1214367.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 275545.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1247899.0
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 8572.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 3693012.0
#                 },
#                 {
#                     "name": "Bonaire Sint Eustatius and Saba",
#                     "value": null
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 738521.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 541009.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 3109.0
#                 },
#                 {
#                     "name": "Greenland",
#                     "value": null
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 771879.0
#                 },
#                 {
#                     "name": "European Union",
#                     "value": 32685690.0
#                 },
#                 {
#                     "name": "Lower middle income",
#                     "value": 43070506.0
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 238013.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 30557.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 13752.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 10688.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 576936.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 380457.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value"
